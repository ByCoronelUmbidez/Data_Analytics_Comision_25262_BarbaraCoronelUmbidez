# %% [markdown]
# Pre‑Entrega de Proyecto
#
# Datasets: ventas.csv, clientes.csv, marketing.csv (en Drive).
#
# Etapa 1: Recopilación y Preparación de Datos (Clases 1 a 4)
#
# 1. Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.
# 2. Realizar un script básico que calcule las ventas mensuales utilizando variables y operadores. (opcional)
# 3. Estructuras de Datos: Desarrollar un programa que almacene los datos de ventas (producto, precio, cantidad). Decidir si conviene utilizar diccionarios o listas. (opcional)
# 4. Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.
# 5. Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.
#
# Etapa 2: Preprocesamiento y Limpieza de Datos (Clases 5 a 8)
#
# 6. Limpieza de Datos: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.
# 7. Transformación de Datos: Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.
# 8. Agregación: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# 9. Integración de Datos: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.

# %% [markdown]
# 1.   Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.

# %%
#Importación de librerias
import pandas as pd
import numpy as np

#Conexión de la unidad
from google.colab import drive
drive.mount('/content/drive')

# Para evitar errores voy a verificar que los archivos csv se encuentren en la carpeta datasets
import os
os.listdir("/content/drive/MyDrive/datasets")

# Ahora especifico la ruta de los archivos
ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_clientes = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"

# Cargo los CSV como DataFrames.
ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_clientes)
marketing = pd.read_csv(ruta_marketing)

# Verifico que se cargaron correctamente
print("ventas.shape ->", ventas.shape)
print("clientes.shape ->", clientes.shape)
print("marketing.shape ->", marketing.shape)

# Entonces muestro las primeras filas de cada dataset para corroborar estructura de columnas.
display(ventas.head(3))
display(clientes.head(3))
display(marketing.head(3))
# Out:
# Mounted at /content/drive
# ventas.shape -> (3035, 6)
# clientes.shape -> (567, 5)
# marketing.shape -> (90, 6)
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
